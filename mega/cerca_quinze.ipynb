# %%
import lib.lib_cerca_quinze as quinze
import lib.gera_sessenta as sessenta

# %%
result = sessenta.gera_sessenta()

# %%
quinze.show(result)
# Out:
# ------------------------------------------------------------------------------------------
# ['36', '41', '10', '26', '07', '23', '09', '14', '06', '16', '17', '24', '53', '56', '21']
# |Qtde Números:15	|Média:29.916666666666668	|Qtde par:08	|Qtde impar:07
# ------------------------------------------------------------------------------------------
# ['43', '08', '54', '19', '02', '03', '28', '60', '18', '55', '44', '20', '48', '50', '39']
# |Qtde Números:15	|Média:40.916666666666664	|Qtde par:10	|Qtde impar:05
# ------------------------------------------------------------------------------------------
# ['59', '37', '57', '58', '33', '40', '30', '52', '46', '22', '32', '15', '49', '45', '05']
# |Qtde Números:15	|Média:48.333333333333336	|Qtde par:07	|Qtde impar:08
# ------------------------------------------------------------------------------------------
# ['27', '38', '11', '04', '47', '25', '31', '12', '01', '13', '42', '51', '34', '35', '29']
# ...

# %%
matriz_geradora = quinze.matriz_geradora()

# %%
x = 0
for parte in quinze.quatro_partes(result):
    x += 1
    nome_arquivo = 'csv/2020_parte_{:02.0f}.csv'.format(x)
    print(nome_arquivo)
    y = 0
    jogo = []
    for mg in matriz_geradora:
        y += 1
        jogo.append(quinze.gera_sena(mg,parte))
        print('S{:02.0f} -> {}'.format(y, quinze.gera_sena(mg,parte)))
    quinze.grava_partes(nome_arquivo,jogo)    
    print()
# Out:
# csv/2020_parte_01.csv
# S01 -> ['07', '10', '23', '26', '36', '41']
# S02 -> ['06', '09', '10', '14', '36', '41']
# S03 -> ['10', '16', '17', '24', '36', '41']
# S04 -> ['10', '21', '36', '41', '53', '56']
# S05 -> ['06', '07', '09', '14', '23', '26']
# S06 -> ['07', '16', '17', '23', '24', '26']
# S07 -> ['07', '21', '23', '26', '53', '56']
# S08 -> ['06', '09', '14', '16', '17', '24']
# S09 -> ['06', '09', '14', '21', '53', '56']
# S10 -> ['16', '17', '21', '24', '53', '56']
# Gravado como "csv/2020_parte_01.csv"
#
# csv/2020_parte_02.csv
# S01 -> ['02', '03', '08', '19', '43', '54']
# S02 -> ['08', '18', '28', '43', '54', '60']
# S03 -> ['08', '20', '43', '44', '54', '55']
# S04 -> ['08', '39', '43', '48', '50', '54']
# S05 -> ['02', '03', '18', '19', '28', '60']
# S06 -> ['02', '03', '19', '20', '44', '55']
# S07 -> ['02', '03', '19', '39', '48', '50']
# S08 -> ['18', '20', '28', '44', '55', '60']
# S09 -> ['18', '28', '39', '48', '50', '60']
# ...
